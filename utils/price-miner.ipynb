# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import pandas as pd  

def browser_init():
    options = webdriver.ChromeOptions()
    options.add_argument("--start-maximized")
    browser = webdriver.Chrome(options=options)
    return browser 


def do_search(browser, url, input_element, item):
    browser.get(url)
    search_input = browser.find_element_by_xpath(input_element)
    search_input.send_keys(item)
    search_input.send_keys(Keys.ENTER)
    sleep(1)
    
    
def mercadolivre(item, max_items):
    filtered_prices, names, formatted_prices, filtered_links = [], [], [], [] 
    url = 'http://mercadolivre.com.br'
    input_element = '/html/body/header/div/form/input'
    browser = browser_init()
    do_search(browser, url, input_element, item)
    
    for i in range(2, 0, -1):
        browser.find_element_by_xpath('//*[@id="root-app"]/div/div[1]/section/div[1]/div/div/div[2]/div[1]/div/div/button').click()
        browser.find_element_by_xpath(f'//*[@id="root-app"]/div/div[1]/section/div[1]/div/div/div[2]/div[1]/div/div/div/ul/li[{i}]').click() 
    
    name_elements  = browser.find_elements_by_class_name('ui-search-item__title')
    price_elements = browser.find_elements_by_class_name('price-tag-fraction')
    link_elements  = browser.find_elements_by_class_name('ui-search-link')
    
    for i in range(0, len(price_elements), 2):
        filtered_prices.append(price_elements[i])
   
    del link_elements[0:6]
    
    for i in range(0, (max_items+(max_items-1)), 2):
        filtered_links.append(link_elements[i].get_attribute('href'))
        
    for i in range(0, max_items):
        names.append(name_elements[i].text)
        formatted_prices.append(f'R$ {filtered_prices[i].text}')
        
    data = {'Mercado Livre - Nome':names, 'Preço': formatted_prices, "Link": filtered_links}        
    browser.close()
    return pd.DataFrame(data)


def kabum(item, max_items):
    names, formatted_prices, filtered_links = [], [], []
    url = 'http://kabum.com.br'
    input_element = '/html/body/div[2]/header/div[1]/div/div[4]/form/input[1]'
    browser = browser_init()
    do_search(browser, url, input_element, item)
    
    name_elements = browser.find_elements_by_class_name('item-nome')
    price_elements = browser.find_elements_by_class_name('sc-fznWqX')
    
    for i in range(0, max_items):
        names.append(name_elements[i].text)
        
    for i in range(0, max_items):
        formatted_prices.append(price_elements[i].text)
    
    for i in range(0, max_items):
        filtered_links.append(name_elements[i].get_attribute('href'))
        
    data = {'Kabum - Nome':names, 'Preço': formatted_prices, 'Links': filtered_links}  
    browser.close()
    return pd.DataFrame(data)
    
def amazon(item, max_items):
    names, formatted_prices, filtered_links = [], [], []
    url = 'http://amazon.com.br'
    input_element = '//*[@id="twotabsearchtextbox"]'
    browser = browser_init()
    do_search(browser, url, input_element, item)    
    
    name_elements = browser.find_elements_by_class_name('a-size-base-plus')
    price_elements = browser.find_elements_by_class_name('a-offscreen')
    
    del name_elements[0:4]
    for i in range(0, max_items):
        print(name_elements[i].text)


#item = input("O que deseja pesquisar?")
#max_items = int(input('Quantos itens? ')) + 1

item = 'ssd 480GB'
max_items = 10
#amazon(item, max_items)
display(kabum(item, max_items))
display(mercadolivre(item, max_items))
# Out:
#                                         Kabum - Nome        Preço  \
# 0  SSD Lexar NQ100 SATAIII 480GB, Leituras: 560Mb...    R$ 389,90
# 1  SSD Kingston A400, 480GB, SATA, Leitura 500MB/...    R$ 429,90
# 2  SSD Crucial BX500, 480GB, SATA, Leitura 540MB/...    R$ 424,90
# 3  SSD WD Green, 480GB, SATA, Leitura 545MB/s, Gr...    R$ 439,90
# 4  SSD Sandisk Plus, 480GB, SATA, Leitura 535MB/s...    R$ 479,90
# 5  SSD WD Green, 480GB, M.2, Leitura 545MB/s - WD...    R$ 419,90
# 6  SSD PNY CS900, 480GB, SATA 2.5´, Leituras: 550...    R$ 459,90
# 7  SSD Externo Adata SD600Q, 480GB, SATA, Leitura...    R$ 461,90
# 8  Computador Gamer Concórdia, Processador Ryzen ...  R$ 4.399,90
# 9  SSD Adata SU635, 480GB, SATA, Leituras: 520MB/...    R$ 449,90
#
#                                                Links
# 0  https://www.kabum.com.br/produto/128075/ssd-le...
# 1  https://www.kabum.com.br/produto/85198/ssd-kin...
# 2  https://www.kabum.com.br/produto/98545/ssd-cru...
# 3  https://www.kabum.com.br/produto/98432/ssd-wd-...
# 4  https://www.kabum.com.br/produto/80575/ssd-san...
# 5  https://www.kabum.com.br/produto/98433/ssd-wd-...
# 6  https://www.kabum.com.br/produto/115749/ssd-pn...
# 7  https://www.kabum.com.br/produto/103521/ssd-ex...
# 8  https://www.kabum.com.br/produto/133953/comput...
# 9  https://www.kabum.com.br/produto/114872/ssd-ad...
#                                 Mercado Livre - Nome     Preço  \
# 0  Disco sólido interno Kingston SA400S37/120G 120GB    R$ 199
# 1  Disco sólido interno Kingston SA400S37/480G 480GB    R$ 442
# 2  Disco sólido interno Kingston SQ500S37/480G 480GB    R$ 479
# 3  Disco sólido interno SanDisk SSD Plus SDSSDA-4...    R$ 459
# 4  Disco sólido interno Western Digital WD Green ...    R$ 420
# 5  Disco sólido interno Crucial CT480BX500SSD1 480GB    R$ 428
# 6  Disco sólido interno Adata Ultimate SU630 ASU6...    R$ 452
# 7  Disco sólido interno Kingston SEDC500R/480G 480GB  R$ 1.165
# 8   Disco sólido interno Kingston SA400M8/480G 480GB    R$ 478
# 9  Disco sólido interno Western Digital WD Green ...    R$ 499
#
#                                                 Link
# 0  https://www.mercadolivre.com.br/disco-solido-i...
# 1  https://www.mercadolivre.com.br/disco-solido-i...
# 2  https://www.mercadolivre.com.br/disco-solido-i...
# 3  https://www.mercadolivre.com.br/disco-solido-i...
# 4  https://www.mercadolivre.com.br/disco-solido-i...
# 5  https://www.mercadolivre.com.br/disco-solido-i...
# 6  https://www.mercadolivre.com.br/disco-solido-i...
# 7  https://www.mercadolivre.com.br/disco-solido-i...
# 8  https://www.mercadolivre.com.br/disco-solido-i...
# 9  https://www.mercadolivre.com.br/disco-solido-i...
